# %% [markdown]
# # conditional statements in python
# 1. python have 4 types of conditioal statments
# 2. `if` statement
# 3. `elif` statement
# 4. `esle` statement
# 5. `nested` statement
#
# ```python -if
# if (condition) #if condition true inside statments are running
#     statement1
#     statements...
# ```
#
# ```python - if,else
# if (condition)#if condition true inside statements are running
#     statement1
#     statements2...n
# else:#if condition fails went ton else statement and print inside statements
#    statement1
#    statement2...n
# ```
#
# ```python - if,elif,else
# if (condition):
#     statements
# elif (condition):
#     statements
# elif (condition):
#     statements
# else:
#     statements
# ```

# %%
# write a program to find the given is even number?
number= int(input("enter number here:"))
if (number%2 ==0):
    print(number,"is even number")
# Out:
# enter number here: 2
# 2 is even number

# %%
101%2
# Out:
# 1

# %%
# write a programe to find the given number is even or odd number? 
num =int(input("please enter number here:"))
if (num%2==1): 
    print(num,"is odd number")
else : 
    print (num,"is even number")
# Out:
# please enter number here: 746890
# 746890 is even number

# %%
# write a program to find the given number is positive or negative or zero?
n =int(input("please enter number here:"))
if (n>0):
   print(n,"is positive number")
elif(n<0):
  print(n,"is negative number")
else: 
    print(n,"is zero")
# Out:
# please enter number here: 0
# 0 is zero

# %%
# write a program to find the largest number from three number?
v1 = int(input("enter first number here:"))
v2 = int(input("enter second number here :"))
v3 = int(input("enter third number here:"))
if (v1>=v2 and v1>=v3):
    print (v1, " is the largest number")
elif (v2>=v1 and v2>=v3 ):
    print (v2," is the largest number")
else:
    print(v3, "is the largest number")
# Out:
# enter first number here: 100
# enter second number here : 100
# enter third number here: 20
# 100  is the largest number

# %%
"""
write a program to find the grades based on student marks 
1. if marks in between 80 to 100 - A grade 
2. if marks in between 60 to 79 - B grade 
3. if marks in between 40 to 59 - C grade 
4. if marks in between 25 to 39 - D grade 
5. oif marks in between 0 to 24 - failn
6. if other than above marks out is - please enter correct marks 

""" 

marks = int(input("enter student marks here :"))
if (marks >=80 and marks<=100): 
   print (marks , "A grade") 
elif (marks>=60 and marks<=79):
     print (marks,"B grade ")
elif ( marks>=40 and marks<=59):
     print (marks,"c grade")
elif ( marks>=25 and marks<=39):
     print (marks, "D grade")
elif (marks>=0 and marks<=24):
    print (marks, "FAIL")
else: 
    print ("please enter correct marks ")
# Out:
# enter student marks here : -72
# please enter correct marks

# %%
#write a program to volid login credentials using conditional statements 
username=str(input("please enter username here:"))  
if (username=="sree_and_slay"):
    print ("username is valid")
    password = str(input("please enter password here:"))
    if (password== "Slovv@123"):
        print ("user cerdentias are successfully valid")
    else:
        print ( "password is invalid")
else: 
    print( "username is invalid")
# Out:
# please enter username here: Sree_and_slay
# username is invalid
