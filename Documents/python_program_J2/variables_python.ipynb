# %% [markdown]
# # variables in python
# 1. variable is memory alloctaion to a value
# 2. examples are `name"yashasree"` `age =16`

# %%
name ="yashasree"
age= 16
salary=10000.65
print(name)
print(age)
print(salary)
# Out:
# yashasree
# 16
# 10000.65

# %% [markdown]
# # key pointsto define variables
# 1. variables does not start with digit
# 2. variables does not allow special characters
# 3. do not use keywords as a variables

# %%
1name="yashasree"
print(1name)
# Out:
#   Cell In[2], line 1
#     1name="yashasree"
#     ^
# SyntaxError: invalid decimal literal

# %%
first@name="yashasree"
print(first@name)
# Out:
#   Cell In[3], line 1
#     first@name="yashasree"
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
first_name="yashasree"
print(first_name)
# Out:
# yashasree

# %%
for="yashasree"
print(for)
# Out:
#   Cell In[5], line 1
#     for="yashasree"
#        ^
# SyntaxError: invalid syntax

# %%
for1="yashasree"
print(for1)
# Out:
# yashasree
